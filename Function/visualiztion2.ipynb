# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# box plot
x=np.array([1,4,1,5,2,8,7,9,4,5,2,5,1,6,7,5,4,6,1,5])
x.shape
# Out:
# (20,)

# %%
plt.boxplot(x, notch=True, vert=False)
plt.show()

# %%
plt.hist(x, bins=range(0,x.max()+1,2), edgecolor='black')
plt.grid()
plt.xticks()
plt.yticks([])
plt.show()

# %%
gap=range(0,x.max()+1,2)
plt.hist(x, bins=gap, edgecolor='black')

plt.grid()
plt.xticks(gap)
plt.yticks(range(0,8+1,2))
plt.show()
type(gap)
# Out:
# range

# %%
# scatter.plot
x=np.random.randn(100)

y=np.random.randn(100)

plt.scatter(x,y,s=100,alpha=.5,c='#ff0000')# alpha is for transpirancy
plt.show()

# %%
# scatter.plot
x=np.random.randn(100)
y=np.random.randn(100)
plt.scatter(x,y,s=100,alpha=.5,c=y,cmap='gist_rainbow')
plt.colorbar()
plt.show()

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(data=df, x='tip')

# %%
sns.displot(data=df, x='total_bill',col='sex',row='time')
