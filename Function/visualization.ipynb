# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t= np.linspace(0,2*np.pi,100)
x=np.sin(t)
y=np.cos(t)

# %%
plt.figure(figsize=(15,7))
plt.plot(t,x,marker='o',markeredgecolor='blue',markersize=20,markerfacecolor="yellow")
plt.plot(t,y,'x-',markersize=5)
